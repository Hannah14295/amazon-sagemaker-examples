# %% [markdown]
# # NTE pass demo
# Minimal notebook to validate the Notebook Test Engine PR trigger end-to-end (happy path). Every cell is designed to execute successfully.

# %%
# Trivial, dependency-free work so the engine runs the notebook and it passes cleanly.
message = "NTE happy-path test: success"
print(message)

# %%
# Simple assertion that always holds -- confirms cell execution completed without error.
total = sum(range(10))
assert total == 45, f"unexpected total: {total}"
print(f"sum(range(10)) = {total}; all checks passed")
