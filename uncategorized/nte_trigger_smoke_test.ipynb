# %% [markdown]
# # NTE trigger smoke test
# Minimal notebook to validate the Notebook Test Engine PR trigger end-to-end (fail path).

# %%
raise RuntimeError("NTE fail-path test: intentional failure")
